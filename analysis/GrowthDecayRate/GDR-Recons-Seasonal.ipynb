# %% [markdown]
# # **ENSO Growth/Decay Rate Experiment Split by Eruption Seasonality - Reconstructions**
#
# Runs Both:
#
# (1) Unconditional (all eruptions)
#
# (2) Phase-conditioned (eruption-year phase = El Niño / Neutral / La Niña)
#
# Output:
#
# -  CSV saved to ~/ENSO-GDR-Recons-Seasonal.csv

# %%
import numpy as np
import pandas as pd


# SETTINGS

file_path = "/home/563/ft3359/ENSO_Records_all.csv"
YEAR_COL = "Years"

RECON_COLUMNS = [
    "Zhu et al. (2022) Li13b6.",
    "Wilson et al. (2010) Nino34 COAPCR",
    "Freund et al. (2019) Nino4 DJF",
    "Li et al. (2011) NADA PC1",
    "Stahle et al. (1993)",
    "DArrigo et al. (2005) Nino3",
    "Datwyler et al. (2020) ENSO DJF",
    "Geay et al. (2013) Nino3",
    "Liu et al. (2024) PCR",
]

PRE_YEARS = 5
POST_YEARS = 5
FIT_START = 0
FIT_END = 3
THRESHOLD_RAW = 0.5

EXCLUDE_MARGIN_YEARS = 5
N_MC = 6000
SEED = 42
MIN_VALID_EVENTS = 2
LOG_TOL = 1e-6

SEASONS = ["DJF", "MAM", "JJA", "SON"]
PHASES = ["El Niño", "Neutral", "La Niña"]

# ERUPTION LIST: all 20 eruptions (850-1849 CE) with known seasonality.

ERUPTIONS_RAW = [
    (939.0,  4.0,  1.0,  63.6, -1.0, 16.23, 4.97),
    (946.0, 11.0,  1.0,  42.0, -1.0,  1.72, 0.61),
    (1257.0, 7.0,  1.0,  -8.4,  1.4, 59.42, 10.86),
    (1477.0, 2.0,  1.0,  64.6, -1.0,  5.12, 1.61),
    (1510.0, 7.0, 25.0,  64.0, -1.0,  2.30, 0.83),
    (1585.0, 1.0, 10.0,  19.5, 10.6,  8.51, 2.34),
    (1595.0, 3.0,  1.0,   4.9,  0.8,  8.87, 1.51),
    (1600.0, 2.0, 17.0, -16.6,  2.0, 18.95, 4.03),
    (1640.0, 12.0, 26.0,  6.1,  2.8, 18.68, 4.28),
    (1667.0, 9.0, 23.0,  42.7, -1.0,  3.48, 1.11),
    (1673.0, 5.0, 20.0,   1.4,  0.7,  4.67, 0.82),
    (1707.0, 12.0, 16.0,  35.4, -1.0,  1.08, 0.40),
    (1721.0, 5.0, 11.0,  63.6, -1.0,  0.81, 0.36),
    (1739.0, 8.0, 19.0,  42.7, -1.0,  3.44, 1.09),
    (1755.0, 10.0, 17.0,  63.6, -1.0,  1.18, 0.43),
    (1766.0, 4.0,  5.0,  64.0, -1.0,  2.52, 0.75),
    (1783.0, 6.0, 15.0,  64.4, -1.0, 20.81, 7.04),
    (1815.0, 4.0, 10.0,  -8.0,  0.8, 28.08, 4.49),
    (1822.0, 10.0,  8.0,  -7.3, 10.0,  2.02, 0.79),
    (1835.0, 1.0, 20.0,  13.0,  2.0,  9.48, 2.21),
]
eruptions_df = pd.DataFrame(
    ERUPTIONS_RAW,
    columns=["yearCE", "month", "day", "lat", "hemi", "ssi", "sigma_ssi"],
)

eruption_years = eruptions_df["yearCE"].to_numpy(dtype=int)

# Season classification
def classify_season(month: float) -> str:
    m = int(month)
    if m in (12, 1, 2):
        return "DJF"
    if m in (3, 4, 5):
        return "MAM"
    if m in (6, 7, 8):
        return "JJA"
    if m in (9, 10, 11):
        return "SON"
    return None

eruptions_df["season"] = eruptions_df["month"].apply(classify_season)
SEASON_BY_YEAR = dict(zip(eruptions_df["yearCE"].astype(int), eruptions_df["season"]))

# LOAD DATA
df = pd.read_csv(file_path)
df.columns = (
    df.columns.astype(str)
    .str.replace(r"^'+|'+$", "", regex=True)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

if YEAR_COL not in df.columns:
    raise KeyError(f"'{YEAR_COL}' not found. Found:\n{list(df.columns)}")

df[YEAR_COL] = pd.to_numeric(df[YEAR_COL], errors="coerce")
df = df.dropna(subset=[YEAR_COL]).copy()
df[YEAR_COL] = df[YEAR_COL].astype(int)
df = df.set_index(YEAR_COL).sort_index()

for c in df.columns:
    df[c] = pd.to_numeric(df[c], errors="coerce")

missing = [c for c in RECON_COLUMNS if c not in df.columns]
if missing:
    raise KeyError(
        "Requested reconstruction columns not found:\n"
        + "\n".join(f" - {m}" for m in missing)
    )

# %%
# HELPERS

def classify_years_all(series_raw, threshold=0.5):
    el, neu, la = [], [], []
    for y, v in series_raw.items():
        if not np.isfinite(v):
            continue
        if v >= threshold:
            el.append(int(y))
        elif v <= -threshold:
            la.append(int(y))
        else:
            neu.append(int(y))
    return np.array(el, dtype=int), np.array(neu, dtype=int), np.array(la, dtype=int)


def build_all_windows(series_sd, pre_years=5, post_years=5):
    years = series_sd.index.values.astype(int)
    vals = series_sd.values.astype(float)
    year_to_i = {int(y): i for i, y in enumerate(years)}

    lags = np.arange(-pre_years, post_years + 1, dtype=int)
    windows = []
    years_win = []

    for center in years:
        center = int(center)
        w = []
        ok = True
        for lag in lags:
            yy = center + int(lag)
            if yy not in year_to_i:
                ok = False
                break
            v = vals[year_to_i[yy]]
            if not np.isfinite(v):
                ok = False
                break
            w.append(v)
        if ok:
            windows.append(w)
            years_win.append(center)

    if len(windows) == 0:
        return lags, None, None

    return lags, np.asarray(windows, dtype=float), np.asarray(years_win, dtype=int)


def composite_from_years(windows, years_win, event_years):
    event_years = np.asarray(event_years, dtype=int)
    if event_years.size == 0:
        return None, 0
    mask = np.isin(years_win, event_years)
    if not np.any(mask):
        return None, 0
    W = windows[mask]
    return np.mean(W, axis=0), int(W.shape[0])


def fit_exponential_rate(comp, pre_years=5, fit_start=0, fit_end=3, tol=1e-6):
    if comp is None:
        return np.nan, np.nan

    idx0 = pre_years + fit_start
    idx1 = pre_years + fit_end + 1
    y = np.asarray(comp[idx0:idx1], dtype=float)

    if np.sum(np.isfinite(y)) < 3:
        return np.nan, np.nan

    tail = y[-2:]
    if np.sum(np.isfinite(tail)) == 0:
        return np.nan, np.nan
    C = np.nanmedian(tail)

    dev = np.abs(y - C)
    valid = np.isfinite(dev) & (dev > tol)

    if np.sum(valid) < 3:
        return np.nan, np.nan

    t = np.arange(fit_start, fit_end + 1, dtype=float)[valid]
    log_dev = np.log(dev[valid])

    try:
        r, alpha = np.polyfit(t, log_dev, 1)
    except Exception:
        return np.nan, np.nan

    tau = -1.0 / r if np.isfinite(r) and (r < 0) else np.nan
    return float(r), float(tau) if np.isfinite(tau) else np.nan


def make_control_pool_mask(years_win, eruption_years, exclude_margin_years=5):
    ok = np.ones_like(years_win, dtype=bool)
    for ey in eruption_years:
        ey = int(ey)
        ok &= ~((years_win >= ey - exclude_margin_years) & (years_win <= ey + exclude_margin_years))
    return ok


def mc_pvalue_for_case(
    windows,
    years_win,
    observed_years,
    control_pool_years,
    n_mc=6000,
    seed=42,
    pre_years=5,
    fit_start=0,
    fit_end=3,
    tol=1e-6
):
    observed_years = np.asarray(observed_years, dtype=int)
    control_pool_years = np.asarray(control_pool_years, dtype=int)

    if observed_years.size < MIN_VALID_EVENTS:
        return np.nan, np.nan, np.nan

    obs_comp, n_events = composite_from_years(windows, years_win, observed_years)
    if n_events < MIN_VALID_EVENTS or obs_comp is None:
        return np.nan, np.nan, np.nan

    r_obs, tau_obs = fit_exponential_rate(
        obs_comp, pre_years=pre_years, fit_start=fit_start, fit_end=fit_end, tol=tol
    )

    if not np.isfinite(r_obs):
        return np.nan, np.nan, np.nan

    years_win_set = set(int(y) for y in years_win)
    control_candidates = np.array(
        [int(y) for y in control_pool_years if int(y) in years_win_set], dtype=int
    )
    control_candidates = np.unique(control_candidates)

    if control_candidates.size < n_events:
        return r_obs, tau_obs, np.nan

    rng = np.random.default_rng(seed)
    r_null = []

    for _ in range(n_mc):
        draw = rng.choice(control_candidates, size=n_events, replace=False)
        comp_mc, _ = composite_from_years(windows, years_win, draw)
        r_mc, _ = fit_exponential_rate(
            comp_mc, pre_years=pre_years, fit_start=fit_start, fit_end=fit_end, tol=tol
        )
        if np.isfinite(r_mc):
            r_null.append(r_mc)

    if len(r_null) == 0:
        return r_obs, tau_obs, np.nan

    r_null = np.asarray(r_null, dtype=float)
    r_med = np.nanmedian(r_null)
    p = np.mean(np.abs(r_null - r_med) >= np.abs(r_obs - r_med))

    return r_obs, tau_obs, float(p)

# %%
# MAIN
rows = []

for recon_name in RECON_COLUMNS:
    print(f"{recon_name}")

    series_raw = df[recon_name].dropna()
    if series_raw.empty:
        print("  -> No data; skipping.")
        continue

    std_raw = float(series_raw.std())
    if (not np.isfinite(std_raw)) or std_raw == 0:
        print("  -> Invalid std; skipping.")
        continue

    mean_raw = float(series_raw.mean())
    series_sd = (series_raw - mean_raw) / std_raw

    lags, windows, years_win = build_all_windows(series_sd, PRE_YEARS, POST_YEARS)
    if windows is None:
        print("  -> No valid windows; skipping.")
        continue

    el_all, neu_all, la_all = classify_years_all(series_raw, THRESHOLD_RAW)

    valid_years = set(int(y) for y in years_win)
    eru_valid = np.array([y for y in eruption_years if int(y) in valid_years], dtype=int)

    el_set, neu_set, la_set = set(el_all), set(neu_all), set(la_all)
    phase_sets = {"El Niño": el_set, "Neutral": neu_set, "La Niña": la_set}

    pool_mask = make_control_pool_mask(years_win, eruption_years, EXCLUDE_MARGIN_YEARS)
    control_years_all = years_win[pool_mask]

    control_years_by_phase = {
        "El Niño": np.array([y for y in control_years_all if y in el_set]),
        "Neutral": np.array([y for y in control_years_all if y in neu_set]),
        "La Niña": np.array([y for y in control_years_all if y in la_set]),
    }

    # Season x Phase-conditioned cases (non-pooled — this reconstruction only)
    for season in SEASONS:
        for phase in PHASES:
            eru_sp = np.array(
                [y for y in eru_valid
                 if SEASON_BY_YEAR.get(int(y)) == season and int(y) in phase_sets[phase]],
                dtype=int
            )

            case_name = f"{season} | {phase}"
            n_events = len(eru_sp)

            if n_events < MIN_VALID_EVENTS:
                rows.append({
                    "dataset": recon_name,
                    "season": season,
                    "phase": phase,
                    "case": case_name,
                    "N_events": n_events,
                    "r_yr1": np.nan,
                    "tau_yr": np.nan,
                    "p_value": np.nan
                })
                continue

            seed_case = abs(hash((recon_name, case_name, SEED))) % (2**32)

            r_obs, tau_obs, p_val = mc_pvalue_for_case(
                windows, years_win, eru_sp, control_years_by_phase[phase],
                N_MC, seed_case, PRE_YEARS, FIT_START, FIT_END, LOG_TOL
            )

            rows.append({
                "dataset": recon_name,
                "season": season,
                "phase": phase,
                "case": case_name,
                "N_events": n_events,
                "r_yr1": r_obs,
                "tau_yr": tau_obs,
                "p_value": p_val
            })

results_df = pd.DataFrame(rows)
# Out:
# Zhu et al. (2022) Li13b6.
# Wilson et al. (2010) Nino34 COAPCR
# Freund et al. (2019) Nino4 DJF
# Li et al. (2011) NADA PC1
# Stahle et al. (1993)
# DArrigo et al. (2005) Nino3
# Datwyler et al. (2020) ENSO DJF
# Geay et al. (2013) Nino3
# Liu et al. (2024) PCR

# %%
# PRINT SUMMARY
print("\nGrowth/Decay rate results (exponential fit), Season x Phase, per reconstruction")
print(f"Composite window: [-{PRE_YEARS},{POST_YEARS}] | Fit window: [{FIT_START},{FIT_END}]")
print(f"Controls exclude ±{EXCLUDE_MARGIN_YEARS} years around eruptions | N_MC={N_MC}")

if not results_df.empty:
    print(results_df[["dataset","season","phase","N_events","r_yr1","tau_yr","p_value"]].to_string(index=False))
else:
    print("No results produced.")


# SAVE CSV
SAVE_CSV = True
OUTPUT_PATH = "/home/563/ft3359/FT-Honours/Honours_Paper/GDR/Seasonal_Analysis/ENSO-GDR-Recons-Seasonal.csv"

if SAVE_CSV and not results_df.empty:
    results_df.to_csv(OUTPUT_PATH, index=False)
    print(f"\nSaved CSV: {OUTPUT_PATH}")
# Out:
# Growth/Decay rate results (exponential fit), Season x Phase, per reconstruction
# Composite window: [-5,5] | Fit window: [0,3]
# Controls exclude ±5 years around eruptions | N_MC=6000
#                            dataset season   phase  N_events     r_yr1    tau_yr  p_value
#          Zhu et al. (2022) Li13b6.    DJF El Niño         1       NaN       NaN      NaN
#          Zhu et al. (2022) Li13b6.    DJF Neutral         2 -0.677397  1.476240 0.264493
#          Zhu et al. (2022) Li13b6.    DJF La Niña         3 -0.432723  2.310946 0.906172
#          Zhu et al. (2022) Li13b6.    MAM El Niño         3 -0.109644  9.120441 0.276278
#          Zhu et al. (2022) Li13b6.    MAM Neutral         0       NaN       NaN      NaN
#          Zhu et al. (2022) Li13b6.    MAM La Niña         2  0.011351       NaN 0.337477
#          Zhu et al. (2022) Li13b6.    JJA El Niño         1       NaN       NaN      NaN
#          Zhu et al. (2022) Li13b6.    JJA Neutral         1       NaN       NaN      NaN
#          Zhu et al. (2022) Li13b6.    JJA La Niña         2  0.120391       NaN 0.237319
#          Zhu et al. (2022) Li13b6.    SON El Niño         0       NaN       NaN      NaN
#          Zhu et al. (2022) Li13b6.    SON Neutral         2  0.247598       NaN 0.442208
#          Zhu et al. (2022) Li13b6.    SON La Niña         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    DJF El Niño         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    DJF Neutral         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    DJF La Niña         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    MAM El Niño         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    MAM Neutral         2  0.193885       NaN 0.471912
# Wilson et al. (2010) Nino34 COAPCR    MAM La Niña         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    JJA El Niño         0       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    JJA Neutral         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    JJA La Niña         1       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    SON El Niño         0       NaN       NaN      NaN
# Wilson et al. (2010) Nino34 COAPCR    SON Neutral         2 -0.089389 11.187088 0.890500
# Wilson et al. (2010) Nino34 COAPCR    SON La Niña         1       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    DJF El Niño         2 -0.270764  3.693251 0.611983
#     Freund et al. (2019) Nino4 DJF    DJF Neutral         0       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    DJF La Niña         1       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    MAM El Niño         2 -0.391611  2.553554 0.789280
#     Freund et al. (2019) Nino4 DJF    MAM Neutral         0       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    MAM La Niña         0       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    JJA El Niño         0       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    JJA Neutral         1       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    JJA La Niña         1       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    SON El Niño         1       NaN       NaN      NaN
#     Freund et al. (2019) Nino4 DJF    SON Neutral         2  0.354053       NaN 0.401169
#     Freund et al. (2019) Nino4 DJF    SON La Niña         0       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    DJF El Niño         2 -0.664717  1.504399 0.462154
#          Li et al. (2011) NADA PC1    DJF Neutral         2 -0.023973 41.714368 0.932822
#          Li et al. (2011) NADA PC1    DJF La Niña         2 -0.801388  1.247835 0.395198
#          Li et al. (2011) NADA PC1    MAM El Niño         2 -0.425355  2.350977 0.889815
#          Li et al. (2011) NADA PC1    MAM Neutral         3  0.017111       NaN 0.992998
#          Li et al. (2011) NADA PC1    MAM La Niña         1       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    JJA El Niño         1       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    JJA Neutral         1       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    JJA La Niña         2 -0.116719  8.567564 0.442740
#          Li et al. (2011) NADA PC1    SON El Niño         1       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    SON Neutral         1       NaN       NaN      NaN
#          Li et al. (2011) NADA PC1    SON La Niña         2 -0.437242  2.287063 0.991333
#               Stahle et al. (1993)    DJF El Niño         0       NaN       NaN      NaN
#               Stahle et al. (1993)    DJF Neutral         1       NaN       NaN      NaN
#               Stahle et al. (1993)    DJF La Niña         1       NaN       NaN      NaN
#               Stahle et al. (1993)    MAM El Niño         0       NaN       NaN      NaN
#               Stahle et al. (1993)    MAM Neutral         2  0.423752       NaN 0.352204
#               Stahle et al. (1993)    MAM La Niña         0       NaN       NaN      NaN
#               Stahle et al. (1993)    JJA El Niño         0       NaN       NaN      NaN
#               Stahle et al. (1993)    JJA Neutral         1       NaN       NaN      NaN
#               Stahle et al. (1993)    JJA La Niña         1       NaN       NaN      NaN
#               Stahle et al. (1993)    SON El Niño         0       NaN       NaN      NaN
#               Stahle et al. (1993)    SON Neutral         1       NaN       NaN      NaN
#               Stahle et al. (1993)    SON La Niña         1       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    DJF El Niño         2 -1.169127  0.855339 0.134000
#        DArrigo et al. (2005) Nino3    DJF Neutral         1       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    DJF La Niña         3 -0.280202  3.568856 0.577500
#        DArrigo et al. (2005) Nino3    MAM El Niño         3 -0.538364  1.857479 0.990167
#        DArrigo et al. (2005) Nino3    MAM Neutral         2  0.003265       NaN 0.823549
#        DArrigo et al. (2005) Nino3    MAM La Niña         0       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    JJA El Niño         0       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    JJA Neutral         2 -0.168660  5.929072 0.857143
#        DArrigo et al. (2005) Nino3    JJA La Niña         1       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    SON El Niño         0       NaN       NaN      NaN
#        DArrigo et al. (2005) Nino3    SON Neutral         2  0.146616       NaN 0.607000
#        DArrigo et al. (2005) Nino3    SON La Niña         1       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    DJF El Niño         2 -0.393828  2.539179 0.995333
#    Datwyler et al. (2020) ENSO DJF    DJF Neutral         2  0.065544       NaN 0.666500
#    Datwyler et al. (2020) ENSO DJF    DJF La Niña         2 -0.234137  4.271010 0.664333
#    Datwyler et al. (2020) ENSO DJF    MAM El Niño         3 -0.522679  1.913221 0.893500
#    Datwyler et al. (2020) ENSO DJF    MAM Neutral         0       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    MAM La Niña         2 -0.013963 71.617940 0.372167
#    Datwyler et al. (2020) ENSO DJF    JJA El Niño         1       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    JJA Neutral         1       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    JJA La Niña         2  0.023280       NaN 0.350167
#    Datwyler et al. (2020) ENSO DJF    SON El Niño         0       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    SON Neutral         1       NaN       NaN      NaN
#    Datwyler et al. (2020) ENSO DJF    SON La Niña         2  0.042209       NaN 0.328167
#           Geay et al. (2013) Nino3    DJF El Niño         2  0.084357       NaN 0.247167
#           Geay et al. (2013) Nino3    DJF Neutral         3  0.778249       NaN 0.098333
#           Geay et al. (2013) Nino3    DJF La Niña         1       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    MAM El Niño         0       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    MAM Neutral         3  0.728998       NaN 0.102534
#           Geay et al. (2013) Nino3    MAM La Niña         2 -0.781695  1.279272 0.387565
#           Geay et al. (2013) Nino3    JJA El Niño         1       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    JJA Neutral         2 -0.141404  7.071958 0.953151
#           Geay et al. (2013) Nino3    JJA La Niña         1       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    SON El Niño         0       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    SON Neutral         1       NaN       NaN      NaN
#           Geay et al. (2013) Nino3    SON La Niña         2  0.019063       NaN 0.297149
#              Liu et al. (2024) PCR    DJF El Niño         2 -0.406701  2.458810 0.991333
#              Liu et al. (2024) PCR    DJF Neutral         2 -0.269931  3.704648 0.606333
#              Liu et al. (2024) PCR    DJF La Niña         2 -0.755589  1.323471 0.420333
#              Liu et al. (2024) PCR    MAM El Niño         3 -0.649613  1.539379 0.662500
#              Liu et al. (2024) PCR    MAM Neutral         0       NaN       NaN      NaN
#              Liu et al. (2024) PCR    MAM La Niña         2 -0.905995  1.103759 0.257167
#              Liu et al. (2024) PCR    JJA El Niño         1       NaN       NaN      NaN
#              Liu et al. (2024) PCR    JJA Neutral         1       NaN       NaN      NaN
#              Liu et al. (2024) PCR    JJA La Niña         2  0.532212       NaN 0.060333
#              Liu et al. (2024) PCR    SON El Niño         1       NaN       NaN      NaN
#              Liu et al. (2024) PCR    SON Neutral         2  0.226043       NaN 0.623167
#              Liu et al. (2024) PCR    SON La Niña         0       NaN       NaN      NaN
#
# Saved CSV: /home/563/ft3359/FT-Honours/Honours_Paper/GDR/Seasonal_Analysis/ENSO-GDR-Recons-Seasonal.csv
